# %% [markdown]
# <CENTER><img src="images/logos.png" style="width:50%"></CENTER>

# %% [markdown]
# <CENTER><h1>Intro to histogramming</h1></CENTER> <a name="c"></a>
#
# In particle physics, we use so many events to make our measurements that looking at the events by hand would be very impractical - instead, we use computer code to do the looking for us.
#
# This notebook will walk you through some basic computing techniques commonly used in high energy physics (HEP) analyses. You will learn how to:
#
# 1. Interact with ATLAS data files
# 2. Create a histogram for displaying data
# 3. Fill your histogram
# 4. Draw your histogram
# 5. Normalise your histogram
#
# We will be showing you examples of these techniques to produce a plot with the __number of leptons__ in each event in a set of 13 TeV Z boson data. At the same time, you will be following along to produce your own plot with the __number of jets__ in each event in a set of 8 TeV W and Z boson data. TeV stands for 'Tera-electron-volt' and is a unit of energy we use in particle physics - we will learn more about the units we use in particle physics in the next notebook!
#
# <table><tr>
#
# <td> <img src="./images/WBoson.png" style="height: 150px;"/> </td>
# </tr></table>

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-success">
#     Before you get into your histogramming and are introduced to Z invariant mass, make sure you review the fundamentals of particle physics and the Standard Model by watching <a href="https://youtu.be/hmM-ic4Wh68"> this</a> RAL video by Dr Emmanuel Olaiya.
# </div>

# %% [markdown]
# **Contents:**
# - [Step 0: What to load](#0.)
# - [Step 1: Working with .root files](#1.)
# - [Step 2: Getting ready to display histograms](#2.)
# - [Step 3: Filling histograms](#3.)
# - [Step 4: Drawing histograms](#4.)
# - [Step 5: Normalising histograms](#5.)
# - [Extension exercises/'Do your own project' ideas](#6.)

# %% [markdown]
# ---

# %% [markdown]
# ## Step 0: What to load <a name="0."></a>

# %% [markdown]
# The software we will use to analyse our ATLAS data is called __uproot__ and __hist__. Using `uproot`, we are able to process large datasets, do statistical analyses, and visualise our data using __hist__. The data is stored in a format called .root

# %%
#Import the uproot library
import uproot

#Here you could also import any other python libraries you would like to use
import matplotlib.pyplot as plt
import numpy as np

#Function to list datafiles from an Open Data collection
#Later in this notebook you will see a link to a document explaining how to find open data files and retrieve their URLs.
from FileRetriever import print_files as print_files

# %% [markdown]
# [Return to contents](#c)

# %% [markdown]
# ---

# %% [markdown]
# ## Step 1: Working with .root files <a name="1."></a>

# %% [markdown]
# Next we have to open the data files that we want to analyze.
#
# As mentioned above, the format for storing physics data - is a _[something].root_ file. For each event in the dataset we could have many particles, and for each particle, there are several __variables__ we measure (e.g. energy, momentum, charge). The structure of a _*.root_ file is as follows:
#
#
# - A _.root_ file stores and keeps track of all this information in a container called a __TTree__.
# - Inside the TTree, each variable that we measure are stored separately in containers called __branches__.
# - Inside each branch, the measurement of that variable for each event is stored.

# %% [markdown]
# <CENTER><img src="./images/root_struct.png" style="width:70%"></CENTER>

# %% [markdown]
# Lets load our _.root_ file using `uproot`'s `uproot.open()` function. The __argument__ inside the brackets tells uproot where to look for the file.

# %%
f = uproot.open("http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_361106.Zee.1largeRjet1lep.root") ## 13TeV sample
#f = uproot.open("http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2016-07-29/MC/mc_105987.WZ.root") ##8 TeV sample

# %% [markdown]
# <div class="alert alert-info">You could uncomment one of the other lines to repeat the analysis we will do below for a different dataset (remember to comment out the top line first).</div>

# %% [markdown]
# <div class="alert alert-success">If you are curious about where the files above come from, check out the instructions for finding the ATLAS Open Data <a href="FindingOpenData.pdf"> here</a>. The cell below shows an example of how you can use the file retreiver to find the web addresses for the files contained within a specific group of records using the DOI at the top of the page:</div>

# %%
#An example of how to print a list of the urls for e.g. https://opendata.cern/record/15000
#This is the 13 TeV sample collection for one large-R jet + 1 lepton events
print_files("10.7483/OPENDATA.ATLAS.FRWJ.4ZQU") #Parameter = DOI from the top of the page, as a string
# Out:
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep.zip
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/Data/data_A.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/Data/data_B.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/Data/data_C.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/Data/data_D.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301322.ZPrime400_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301323.ZPrime500_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301324.ZPrime750_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301325.ZPrime1000_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301326.ZPrime1250_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301327.ZPrime1500_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301328.ZPrime1750_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301329.ZPrime2000_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301330.ZPrime2250_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301331.ZPrime2500_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301332.ZPrime2750_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_301333.ZPrime3000_tt.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_361100.Wplusenu.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_361101.Wplusmunu.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_361102.Wplustaunu.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_361103.Wminusenu.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_361104.Wminusmunu.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_361105.Wminustaunu.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_361106.Zee.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_361107.Zmumu.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_361108.Ztautau.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363356.ZqqZll.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363358.WqqZll.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363360.WplvWmqq.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363489.WlvZqq.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363491.lllv.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363492.llvv.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363493.lvvv.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364100.Zmumu_PTV0_70_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364101.Zmumu_PTV0_70_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364102.Zmumu_PTV0_70_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364103.Zmumu_PTV70_140_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364104.Zmumu_PTV70_140_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364105.Zmumu_PTV70_140_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364106.Zmumu_PTV140_280_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364107.Zmumu_PTV140_280_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364108.Zmumu_PTV140_280_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364109.Zmumu_PTV280_500_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364110.Zmumu_PTV280_500_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364111.Zmumu_PTV280_500_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364113.Zmumu_PTV1000_E_CMS.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364114.Zee_PTV0_70_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364115.Zee_PTV0_70_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364116.Zee_PTV0_70_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364117.Zee_PTV70_140_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364118.Zee_PTV70_140_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364119.Zee_PTV70_140_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364120.Zee_PTV140_280_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364121.Zee_PTV140_280_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364122.Zee_PTV140_280_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364123.Zee_PTV280_500_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364124.Zee_PTV280_500_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364125.Zee_PTV280_500_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364126.Zee_PTV500_1000.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364127.Zee_PTV1000_E_CMS.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364128.Ztautau_PTV0_70_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364129.Ztautau_PTV0_70_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364130.Ztautau_PTV0_70_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364131.Ztautau_PTV70_140_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364132.Ztautau_PTV70_140_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364133.Ztautau_PTV70_140_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364134.Ztautau_PTV140_280_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364135.Ztautau_PTV140_280_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364136.Ztautau_PTV140_280_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364137.Ztautau_PTV280_500_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364138.Ztautau_PTV280_500_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364139.Ztautau_PTV280_500_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364140.Ztautau_PTV500_1000.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364141.Ztautau_PTV1000_E_CMS.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364156.Wmunu_PTV0_70_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364157.Wmunu_PTV0_70_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364158.Wmunu_PTV0_70_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364159.Wmunu_PTV70_140_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364160.Wmunu_PTV70_140_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364161.Wmunu_PTV70_140_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364162.Wmunu_PTV140_280_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364163.Wmunu_PTV140_280_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364164.Wmunu_PTV140_280_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364165.Wmunu_PTV280_500_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364166.Wmunu_PTV280_500_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364167.Wmunu_PTV280_500_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364168.Wmunu_PTV500_1000.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364169.Wmunu_PTV1000_E_CMS.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364170.Wenu_PTV0_70_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364171.Wenu_PTV0_70_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364172.Wenu_PTV0_70_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364173.Wenu_PTV70_140_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364174.Wenu_PTV70_140_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364175.Wenu_PTV70_140_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364176.Wenu_PTV140_280_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364177.Wenu_PTV140_280_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364178.Wenu_PTV140_280_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364179.Wenu_PTV280_500_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364180.Wenu_PTV280_500_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364181.Wenu_PTV280_500_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364182.Wenu_PTV500_1000.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364183.Wenu_PTV1000_E_CMS.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364184.Wtaunu_PTV0_70_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364185.Wtaunu_PTV0_70_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364186.Wtaunu_PTV0_70_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364187.Wtaunu_PTV70_140_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364188.Wtaunu_PTV70_140_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364189.Wtaunu_PTV70_140_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364190.Wtaunu_PTV140_280_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364191.Wtaunu_PTV140_280_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364192.Wtaunu_PTV140_280_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364193.Wtaunu_PTV280_500_CVetoBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364194.Wtaunu_PTV280_500_CFilterBVeto.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364195.Wtaunu_PTV280_500_BFilter.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364196.Wtaunu_PTV500_1000.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_364197.Wtaunu_PTV1000_E_CMS.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_370114.GG_ttn1_1200_5000_1.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_370118.GG_ttn1_1200_5000_600.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_370129.GG_ttn1_1400_5000_1.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_370144.GG_ttn1_1600_5000_1.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_387154.TT_directTT_500_1.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_387157.TT_directTT_500_200.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_387163.TT_directTT_600_1.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_388240.TT_directTT_450_1.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_392217.C1N2_WZ_400p0_0p0_3L_2L7.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_392220.C1N2_WZ_350p0_0p0_3L_2L7.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_392223.C1N2_WZ_500p0_0p0_3L_2L7.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_392226.C1N2_WZ_100p0_0p0_3L_2L7.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_410000.ttbar_lep.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_410011.single_top_tchan.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_410012.single_antitop_tchan.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_410013.single_top_wtchan.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_410014.single_antitop_wtchan.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_410025.single_top_schan.1largeRjet1lep.root
# http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_410026.single_antitop_schan.1largeRjet1lep.root

# %% [markdown]
# Next, to inspect the contents of a _.root_ file, we use the `.keys()` function.

# %%
f.keys()
# Out:
# ['mini;1']

# %% [markdown]
# We can see what this object 'mini' is using the `.classnames()` function.

# %%
f.classnames()
# Out:
# {'mini;1': 'TTree'}

# %% [markdown]
# This means *mini* is a TTree object and should contain all the data we need.  To load the TTree data directly, we can select it using the below code.

# %%
my_tree = f["mini"]

# %% [markdown]
# Alternatively, we can change our file loading code so it specifies the TTree file *mini*.

# %%
my_tree = uproot.open("http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_361106.Zee.1largeRjet1lep.root:mini")

# %% [markdown]
# The `.show()` function allows us to see the full contents of our TTree.

# %%
my_tree.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# runNumber            | int32_t                  | AsDtype('>i4')
# eventNumber          | int32_t                  | AsDtype('>i4')
# channelNumber        | int32_t                  | AsDtype('>i4')
# mcWeight             | float                    | AsDtype('>f4')
# scaleFactor_PILEUP   | float                    | AsDtype('>f4')
# scaleFactor_ELE      | float                    | AsDtype('>f4')
# scaleFactor_MUON     | float                    | AsDtype('>f4')
# scaleFactor_PHOTON   | float                    | AsDtype('>f4')
# scaleFactor_TAU      | float                    | AsDtype('>f4')
# scaleFactor_BTAG     | float                    | AsDtype('>f4')
# scaleFactor_LepTR... | float                    | AsDtype('>f4')
# scaleFactor_Photo... | float                    | AsDtype('>f4')
# trigE                | bool                     | AsDtype('bool')
# trigM                | bool                     | AsDtype('bool')
# trigP                | bool                     | AsDtype('bool')
# lep_n                | uint32_t                 | AsDtype('>u4')
# lep_truthMatched     | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# lep_trigMatched      | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# lep_pt               | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# lep_eta              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# lep_phi              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# lep_E                | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# lep_z0               | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# lep_charge           | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# lep_type             | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# lep_isTightID        | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# lep_ptcone30         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# lep_etcone20         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# lep_trackd0pvunbi... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# lep_tracksigd0pvu... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# met_et               | float                    | AsDtype('>f4')
# met_phi              | float                    | AsDtype('>f4')
# jet_n                | uint32_t                 | AsDtype('>u4')
# jet_pt               | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# jet_eta              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# jet_phi              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# jet_E                | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# jet_jvt              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# jet_trueflav         | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# jet_truthMatched     | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# jet_MV2c10           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# photon_n             | uint32_t                 | AsDtype('>u4')
# photon_truthMatched  | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# photon_trigMatched   | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# photon_pt            | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# photon_eta           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# photon_phi           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# photon_E             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# photon_isTightID     | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# photon_ptcone30      | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# photon_etcone20      | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# photon_convType      | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# tau_n                | uint32_t                 | AsDtype('>u4')
# tau_pt               | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tau_eta              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tau_phi              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tau_E                | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tau_isTightID        | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# tau_truthMatched     | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# tau_trigMatched      | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# tau_nTracks          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# tau_BDTid            | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ditau_m              | float                    | AsDtype('>f4')
# lep_pt_syst          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# met_et_syst          | float                    | AsDtype('>f4')
# jet_pt_syst          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# photon_pt_syst       | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tau_pt_syst          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# XSection             | float                    | AsDtype('>f4')
# SumWeights           | float                    | AsDtype('>f4')
# largeRjet_n          | uint32_t                 | AsDtype('>u4')
# largeRjet_pt         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# largeRjet_eta        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# largeRjet_phi        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# largeRjet_E          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# largeRjet_m          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# largeRjet_truthMa... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# largeRjet_D2         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# largeRjet_tau32      | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# largeRjet_pt_syst    | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tau_charge           | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...

# %% [markdown]
# We see the names of all the different quantities stored. Rather than use the word name (written at the top of the table), we use the word branch. Let's look at an individual branch in this TTree to see its form. We specify what branch we want to look at ("lep_eta") and the type of array we want to output ("np" which is short for numpy array)

# %%
lep_eta = my_tree["lep_eta"].array(library="np")
lep_eta
# Out:
# array([array([-1.8025961, -1.29893  ], dtype=float32),
#        array([ 0.04702532, -0.12980008], dtype=float32),
#        array([ 0.5145523, -0.5389483], dtype=float32), ...,
#        array([-0.24873704], dtype=float32),
#        array([0.63657373, 0.06841107], dtype=float32),
#        array([0.78326404, 0.05061899], dtype=float32)],
#       shape=(53653,), dtype=object)

# %% [markdown]
# In effect, this is a 2D array containing 2 elements: an array of values, and the data type of the array.  It is this method of storing values that allows an array to be 'jagged' - that is, having each row be a different length - without becoming an issue for array manipulation.

# %% [markdown]
# We can see how many events are stored in the tree by looking at the length of the array using the len function

# %%
len(lep_eta)
# Out:
# 53653

# %% [markdown]
# ### Over to you

# %% [markdown]
# __1)__ __Replace the ###'s in the cell below__ to open the _*.root_ data file `"http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2016-07-29/MC/mc_105987.WZ.root"

# %% [markdown]
# <details>
#     <summary>Click here for hint 1: </summary>
#
#     What function did we use above to open a .root file?
# </details>

# %%
my_file = ###

# %% [markdown]
# <details>
#     <summary>Answer: </summary>
#
#     my_file = uproot.open("http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2016-07-29/MC/mc_105987.WZ.root")
# </details>

# %% [markdown]
# __2)__ Load the tree named "mini" stored in the _.*root_ data file. Print the number of events in this tree.

# %% [markdown]
# <details>
#     <summary>Click here for hint 1: </summary>
#     All data is stored in the TTree 'mini'.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 2: </summary>
#     Pick a branch (name) and output it as an array .
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 3: </summary>
#     Look at the length of the array
# </details>

# %%
my_tree = my_file[###]
eventNumber = my_tree[###].array(###)
print(###)

# %% [markdown]
# <details>
#     <summary>Answer: </summary>
#
#     my_tree = my_file["mini"]
#     eventNumber = my_tree["eventNumber"].array(library="np")
#     len(eventNumber)
# </details>

# %% [markdown]
# __3)__ We will also need to create variables for the maximum number of jets and the minimum number of jets seen by a single event in this dataset for later.

# %% [markdown]
# <details>
#     <summary>Click here for hint 1: </summary>
#     The object you need is called "jet_n". Get an array which is the jet_n for each event
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 2: </summary>
#     Numpy has two functions, .min() and .max(), that return the minimum and maximum values of an array.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 3: </summary>
#     Remember the first event is [0]!
# </details>

# %%
import numpy as np

jet_n = my_tree[###].array(###)
minimum = np.min(###)
maximum = np.max(###)
print("Minimum number of jets:", ###)
print("Maximum number of jets;", ###)
      
#Peek inside the first event using list indexing
jet_n_Event1 = jet_n[#] 
print("Number of jets in Event 1:", ###)

# %% [markdown]
# <details>
#     <summary>Answer: </summary>
#
#     import numpy as np
#
#     jet_n = my_tree["jet_n"].array(library="np")
#     minimum = np.min(jet_n)
#     maximum = np.max(jet_n)
#     print("Minimum number of jets:", minimum)
#     print("Maximum number of jets;", maximum)
#
#     jet_n_Event1 = jet_n[0]
#     print("Number of jets in Event 1:", jet_n_Event1)
# </details>

# %% [markdown]
# [Return to contents](#c)

# %% [markdown]
# ---

# %% [markdown]
# ## Step 2: Getting ready to display histograms <a name="2."></a>

# %% [markdown]
# Before we can display any histograms, we must import a few modules:
# - `hist` is a library that handles the generation and customization of histograms
# - `Hist` is a module from `hist` that allows for the generation of a basic histogram

# %%
import hist
from hist import Hist

# %% [markdown]
# Let's generate a regular histogram using `Hist`; we'll use the `hist.axis.Regular()` option, which takes arguments `(bins, lower_lim, upper_lim, label = "axis label")`.  Here, the **bins** of our histogram are 'slices' of the range of values we fill our histogram with.  But what to fill our histogram with?

# %% [markdown]
# A simple choice would be the number of leptons, as we can guess the number of bins and both the upper and lower limits fairly easily; the smallest number of leptons would be $0$ and the largest number $4$ - this corresponds to 5 bins ($0,1,2,3,4$), a lower limit of $0$ and an upper limit of $4$.  Let's implement this:

# %%
hist1 = Hist(hist.axis.Regular(5, -0.5, 4.5, label = "Number of leptons"))

# %% [markdown]
# Note the offset of 0.5 in the range arguments. This shifts the bins so they are centred on 0,1,2,3,4 rather than having their leftmost edges on those values, as is the default.

# %% [markdown]
# <div class="alert alert-info">We don't expect any output to be printed from this step - all we're doing here is telling python the details of the histogram we're planning to fill.</div>

# %% [markdown]
# ### Over to you

# %% [markdown]
# __4)__ Create a template histogram called "Number of jets" to display your plot.

# %% [markdown]
# <details>
#     <summary>Click here for hint 1: </summary>
#     Decide the maximum number of jets you want to display.
#     Our lower axis limit will always be -0.5 and the upper axis limit will be (maximum number of jets) + 0.5.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 2: </summary>
#     Because we want to also include a bin for events with zero jets, our number of bins will be (maximum number of jets) + 1
# </details>

# %%
my_hist = Hist(hist.axis.Regular(###, ###, ###, label = ###))

# %% [markdown]
# <details>
#     <summary>Answer: </summary>
#
#     Using maximum number of jets = e.g. 8:
#
#     my_hist = Hist(hist.axis.Regular(9, -0.5, 8.5, label = "Number of jets"))
# </details>

# %% [markdown]
# [Return to contents](#c)

# %% [markdown]
# ---

# %% [markdown]
# ## Step 3: Filling histograms <a name="3."></a>

# %% [markdown]
# Now to fill our histogram!  The first step is to extract the number of leptons from our TTree using `uproot`.  We'll want to extract it in the form of a `numpy` array like so:

# %%
lep_n = my_tree["lep_n"].array(library="np")

# %% [markdown]
# This is the data we shall use to fill our histogram using the `.fill()` function from `hist`.  It's very simple:

# %%
hist1.fill(lep_n)
# Out:
# Hist(Regular(5, -0.5, 4.5, label='Number of leptons'), storage=Double()) # Sum: 53653.0

# %% [markdown]
# To properly render our histogram, we'll need to plot it using the `.plot()` function from `hist` and the `plt.show()` function from `matplotlib`.  Let's import `matplotlib` and do exactly this.

# %%
hist1.plot()
plt.show()

# %% [markdown]
# <div class="alert alert-info">In later examples, we'll be more picky about the events we put in our histogram, skipping some events in the tree if they don't meet certain criteria. This is called making cuts.</div>

# %% [markdown]
# ### Over to you

# %% [markdown]
# __5)__ Fill your histogram with the number of jets in each event.

# %% [markdown]
# <details>
#     <summary>Click here for hint 1: </summary>
#         Remember: we've already made a template histogram.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 2: </summary>
#         The data you're after is "jet_n".
# </details>

# %%
my_hist.fill(###)
my_hist.###
plt.###

# %% [markdown]
# <details>
#     <summary>Answer: </summary>
#
#     my_hist.fill(jet_n)
#     my_hist.plot()
#     plt.show()
# </details>

# %% [markdown]
# [Return to contents](#c)

# %% [markdown]
# ---

# %% [markdown]
# ## Step 4: Drawing histograms <a name="4."></a>

# %% [markdown]
# Adding a title to a histogram is fairly easy - you simply pass `plt.title()`.

# %%
hist2 = Hist(hist.axis.Regular(5, -0.5, 4.5, label = "Number"))
hist2.fill(lep_n)
hist2.plot()
plt.title("Number of leptons in a 13 TeV dataset")
plt.show()

# %% [markdown]
# We can also include multiple histograms on the same axis, which is useful if you're trying to look for a particularly elusive particle.  Let's start by accessing the necessary `.root` files.

# %%
tr1 = uproot.open("http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363491.lllv.1largeRjet1lep.root:mini")
lep_n1 = tr1["lep_n"].array(library = "np")

# %%
tr2 = uproot.open("http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363492.llvv.1largeRjet1lep.root:mini")
lep_n2 = tr2["lep_n"].array(library = "np")

# %%
tr3 = uproot.open("http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363493.lvvv.1largeRjet1lep.root:mini")
lep_n3 = tr3["lep_n"].array(library = "np")

# %% [markdown]
# Here, the events in question produced leptons and their associated neutrinos.  We're curious as to how many leptons were produced in each event and how these numbers compare, so overlapping our histograms would be preferable. This is a straightforward process. You can fill three separate histograms, and plot them one after the other. Everytime you run `plot()`, it will draw the histogram on top of what is already there. Of course run `plt.show()` to display what you have drawn. Run the cells below as an example.

# %%
#Create the histgrams

ax1 = Hist(hist.axis.Regular(5, -0.5, 4.5, label = "Number of leptons"))
ax2 = Hist(hist.axis.Regular(5, -0.5, 4.5, label = "Number of leptons"))
ax3 = Hist(hist.axis.Regular(5, -0.5, 4.5, label = "Number of leptons"))

# %%
#Fill the histograms

ax1.fill(lep_n1)
ax2.fill(lep_n2)
ax3.fill(lep_n3)
# Out:
# Hist(Regular(5, -0.5, 4.5, label='Number of leptons'), storage=Double()) # Sum: 188814.0

# %%
#Draw one histogram on top of the other and then display the final plot

ax1.plot()
ax2.plot()
ax3.plot()

plt.show()

# %% [markdown]
# Rather than overlay the histograms this stacks the bin contents on top of each other. This is for useful when you want to add data. We can simply add the histograms and then plot the sum

# %%
histo_sum = ax1+ax2+ax3
histo_sum.plot()
plt.show()

# %% [markdown]
# We can also use the `.stack()` function from `hist`, to overlay or stack histograms, though we'll need to prepare a little first.

# %% [markdown]
# Let's start with the axis of our template histogram, which will be the same as our previous histogram on lepton numbers.

# %%
ax = hist.axis.Regular(5, -0.5, 4.5, flow=False, name = "Number of leptons")

# %% [markdown]
# Now we need a 'category axis' or `cax`, which operates in a similar manner to a dictionary.  Its $1^{st}$ argument is a list of histogram labels and its $2^{nd}$ argument is a label for the collective axis.  In effect, each histogram label is like a key, linking each histogram to its name, color and position.

# %%
cax = hist.axis.StrCategory(["lllv", "llvv", "lvvv"], name = "c")

# %% [markdown]
# Now to generate our 'stacked' histogram.  `Hist()` actually takes two arguments - the *axis* and the *category axis*.

# %%
full_hist = Hist(ax, cax)

# %% [markdown]
# `.fill()` also takes two arguments - *data* and *category*.  Let's fill for each dataset.

# %%
full_hist.fill(lep_n1, c = "lllv")
full_hist.fill(lep_n2, c = "llvv")
full_hist.fill(lep_n3, c = "lvvv")
# Out:
# Hist(
#   Regular(5, -0.5, 4.5, underflow=False, overflow=False, name='Number of leptons'),
#   StrCategory(['lllv', 'llvv', 'lvvv'], name='c'),
#   storage=Double()) # Sum: 1058422.0

# %% [markdown]
# Yep, this is impossible to read - particularly as we have no idea which monochrome shade represents which dataset! Lets use the stack method and specify the name of the  label `"c"`. This will overlay this histograms.

# %%
s = full_hist.stack("c")
s.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x122f8bed0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>),
#  StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x1169d16d0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>),
#  StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x1169d0190>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %% [markdown]
# This looks the same as the output from our previous overlay method, as it should! This plot is slightly more discernible, but we still don't know which histogram is which!  We should add  a title and a legend to properly render our stacked histogram, as well as fill it in so the coloured regions are more visible.

# %%
s = full_hist.stack("c")
s.plot(histtype = "fill")
plt.title("Lepton counts per event for multiple datasets")
plt.legend()
plt.show()

# %% [markdown]
# Here, we've used the condition `histtype = "fill"` when plotting our histogram.

# %% [markdown]
# We can 'stack' this histograms so that the bin contents are added. We can do this by setting the stack option to True as follows

# %%
s.plot(stack=True, histtype = "fill")
plt.title("Lepton counts per event for multiple datasets")
plt.legend()
plt.show()

# %% [markdown]
# Again the bin contents look the same as our previous method of just adding the histograms

# %% [markdown]
# Below is an example showing the steps from opening a root file, filling a histogram and plotting the data

# %%
f = uproot.open("http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2016-07-29/MC/mc_105987.WZ.root")
tree = f["mini"]
lep_n = tree["lep_n"].array(library="np")
lep_n

hist_n = Hist(hist.axis.Regular(5, -0.5, 4.5, label = "Number"))
hist_n.fill(lep_n)

hist_n.plot(histtype = "fill")
plt.title("Lepton counts per event for multiple datasets")
plt.show()

# %% [markdown]
# ### Over to you

# %% [markdown]
# __6)__ Display multiple histograms for lepton number on the same plot.  You'll need the below files:
# - 3 leptons - http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363491.lllv.1largeRjet1lep.root
# - 2 leptons - http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363492.llvv.1largeRjet1lep.root
# - 1 lepton - http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363493.lvvv.1largeRjet1lep.root
#
# These come from the dataset containing one large-R jet and at least one lepton - you can explore more using the `print_files()` function and the DOI `"10.7483/OPENDATA.ATLAS.FRWJ.4ZQU"`.

# %% [markdown]
# <details>
#     <summary>Click here for hint 1: </summary>
#         You'll need to access the TTree data for lepton number 3 separate times, 1 for each dataset.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 2: </summary>
#         Think about the bin numbers and boundaries for your axis, and remember that we have 3 datasets now when generating the category axis.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 3: </summary>
#         You'll need to fill your template histogram 3 times.
# </details>

# %%
### Repeat for each root file
tr1 = uproot.open(###)
lep_n1 = tr1[###].array(###)

### Repeat 3 times

ax = hist.axis.Regular(###)
cax = hist.axis.StrCategory([###], name = ###)
full_hist = Hist(###, ###)

full_hist.fill(###, c = ###)
### Repeat 3 times

s = full_hist.stack(###)
s.###
plt.title(###)
plt.###
plt.###

# %% [markdown]
# <details>
#     <summary>Answer: </summary>
#
#     tr1 = uproot.open("http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363493.lvvv.1largeRjet1lep.root:mini")
#     lep_n1 = tr1["lep_n"].array(library = "np")
#
#     tr2 = uproot.open("http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363492.llvv.1largeRjet1lep.root:mini")
#     lep_n2 = tr2["lep_n"].array(library = "np")
#
#     tr3 = uproot.open("http://opendata.cern.ch/eos/opendata/atlas/OutreachDatasets/2020-08-19/1largeRjet1lep/MC/mc_363491.lllv.1largeRjet1lep.root:mini")
#     lep_n3 = tr3["lep_n"].array(library = "np")
#
#     ax = hist.axis.Regular(6, -0.5, 5.5, flow=False, name = "Number of leptons")
#     cax = hist.axis.StrCategory(["3l1v", "2l2v", "1l3v"], name = "c")
#     full_hist = Hist(ax, cax)
#
#     full_hist.fill(lep_n3, c = "3l1v")
#     full_hist.fill(lep_n2, c = "2l2v")
#     full_hist.fill(lep_n1, c = "1l3v")
#
#     s = full_hist.stack("c")
#     s.plot(stack=True, histtype = "fill")
#     plt.title("Lepton counts per event for multiple datasets")
#     plt.legend()
#     plt.show()
# </details>

# %% [markdown]
# [Return to contents](#c)

# %% [markdown]
# ---

# %% [markdown]
# ## Step 5: Normalising histograms <a name="5."></a>

# %% [markdown]
# Often, we are more interested in the __proportions__ of our histogram than the absolute number of events it contains (which can change depending on what dataset you use).  Our final step will be to rescale the y-axis of our histogram to that the histogram's total is equal to 1. This is called __normalisation__.

# %% [markdown]
# Firstly, we must extract the bin values (heights) as an array, which can be done with the `.values` function.

# %%
arr1 = hist1.values()

# %% [markdown]
# We use the `.sum()` function on our array of bin values to sum the values it contains, then create a new array containing each of the original bin values divided by the sum.

# %%
arr2 = arr1/arr1.sum()

# %% [markdown]
# Let's make a new template histogram:

# %%
hist3 = Hist(hist.axis.Regular(5, -0.5, 4.5, flow=False, label = "Number of leptons"))

# %% [markdown]
# Now we assign our normalised bin values to the original bin values.  Here, we use the length of our `values()` array to refer to the index - simply remove 1 from the full length to refer to the final value, as typical of Python indexing.

# %%
binsize = hist1.values()
uplim = len(binsize)-1
hist3[0:uplim] = arr2[0:uplim]

# %% [markdown]
# Let's see what we get!

# %%
hist3.plot(histtype="fill")
plt.show()

# %% [markdown]
# Now let's show that this is normalised - we've already used the function required to do this!

# %%
print(hist3.sum())
# Out:
# 0.999944085139694

# %% [markdown]
# ### Over to you

# %% [markdown]
# __6)__ Normalise your histogram and redraw it.

# %% [markdown]
# <details>
#     <summary>Click here for hint 1: </summary>
#         Use .values() to access the height of each bar in the histogram.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 2: </summary>
#         Use .sum to find the sum of these heights - you'll need to divide each bar's height by the sum.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 3: </summary>
#         Redraw your histogram and assign new values to each bin.
# </details>

# %%
heights = my_hist.###
norm_heights = ###/heights.###
new_hist = Hist(hist.axis.Regular(###, ###, ###, label = ###))
new_hist[###] = norm_heights[###]
new_hist.###
plt.###

# %% [markdown]
# <details>
#     <summary>Answer: </summary>
#
#     heights = my_hist.values()
#     norm_heights = heights/heights.sum()
#     new_hist = Hist(hist.axis.Regular(5, -0.5, 4.5, label = "Number of jets"))
#     new_hist[0:4] = norm_heights[0:4]
#     new_hist.plot(histtype="fill")
#     plt.show()
# </details>

# %% [markdown]
# [Return to contents](#c)

# %% [markdown]
# ---

# %% [markdown]
# ## Optional extra exercises / 'Do your own project' ideas  <a name="6."></a>

# %% [markdown]
# <div class="alert alert-info"> When completing these execises, it is recommended to copy/paste any code you're reusing from above into new cells, to keep the example available for reference.
# <br>
#
# New cells can be added above using `esc` + `a`, below using `esc` + `b`, or using the `Insert` tab at the top of the page.</div>

# %% [markdown]
# 1) Remember how to extract the list of branches from a TTree? Choose a new branch from `my_tree` and repeat steps __4-8__ above to show the distribution of that branch's variable over the dataset.

# %% [markdown]
# <details>
#     <summary>Click here for hint 1: </summary>
#     Many of the branches you look at may be empty. This can happen depending on what the purpose of the simulation was, or, if using real data, what cuts or filters were applied.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 2: </summary>
#     You know for sure that there are leptons, try looking in the branches related to leptons.
# </details>

# %% [markdown]
# 2) Are there any branches in the tree that you do not understand? List up to 3, then explore the
# [ATLAS Open Data Documentation](https://opendata.atlas.cern/docs/documentation/introduction/introductory_page)
# -
# -
# -

# %% [markdown]
# 3) In the worked example in this notebook (not the "Over to You" exercise), we plotted the number of leptons in a file named `mc_361106.Zee.1largeRjet1lep.root` filled with simulated ('Monte-Carlo'/'MC') collisions at an energy of 13 TeV.
#
# The `1largeRjet1lep` part of the file name means the events are filtered so that there is **at least** one lepton and **at least** one big ("large-radius") jet seen in the detector.
#
# Can you guess from another part of the file name what process is being simulated here?

# %% [markdown]
# <details>
#     <summary>Click here for hint 1: </summary>
#     The "Zee" part tells us that the process being simulated is a $Z$ boson which decays to two electrons.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 2: </summary>
#     An explanation of the other parts of the file name:
#
#     - mc: Means that this file has simulated Monte-Carlo, or "MC", data
#
#     - 361106: This is a unique identifying number for each file
# </details>

# %% [markdown]
# Based on the process being simulated in our file, it may be suprising that we observe events with different numbers of leptons in our histogram (e.g. 0 leptons, 1 lepton, 2 leptons...). Why is this suprising, and why do we see this happen?

# %% [markdown]
# <details>
#     <summary>Click here for hint 3: </summary>
#     It is surprising because we are only simulating $Z\rightarrow ee$ events, so with a perfect detector we would expect two leptons every time.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 4: </summary>
#     Even though we are creating two electrons in every simulated event, our real detector (an therefore also the simulated detector in the MC) is not perfect! Often, it can miss a lepton or two, or mistake them for something else.
# </details>

# %% [markdown]
# Using the instructions for finding new datasets in the main repository, find a file (there may be several, equally correct options) with two 'final state' leptons and plot the number of leptons.

# %% [markdown]
# <div class="alert alert-warning">How do the two plots compare?
#
# Do you understand what all the file names mean?
# </div>

# %% [markdown]
# 4) So far, we have only plotted simulated data.
# - Using the instructions above, find the directory containing real collisions with 1 lepton and 1 jet in the final state.
# - You might notice that the real data is split across several different files (e.g. data_A.1largeRjet1lep.root). Fill a histogram showing a branch of your choice with ALL the events in the full dataset

# %% [markdown]
# <details>
#     <summary>Click here for hint 1: </summary>
#     Load in each data file and its TTree under a separate name. Create a list containing all your separate trees:
#
#     my_trees = [tree1,tree2,tree3,tree4] etc.
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 2: </summary>
#     Set up one histogram as usual
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for hint 3: </summary>
#     Add an extra layer to your histogram filling for loop, looping over the events in all of your trees
#
#     for tree in my_trees:
#         for event in tree:
#             ...
# </details>

# %% [markdown]
# 5) So far we have only shown one histogram at a time. Draw two histograms on the same plot to compare them directly e.g. the `n_lepton` branch for the samples with both 1 and 2 final state leptons

# %% [markdown]
# <details>
#     <summary>Click here for hint 1: </summary>
#     Fill two seprate histograms, but only set up 1 plot.
# </details>

# %% [markdown]
# [Return to contents](#c)
#
# ---

# %% [markdown]
# <div class="alert alert-success">
#
# __Congratulations!__ You've worked with actual LHC data like a real particle physicist! To build on this and use this data to make a real-life measurement of the a particle's physics properties, move on to Notebook 4.
#
# </div>
